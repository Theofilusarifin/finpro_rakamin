# %% [markdown]
# ## Load Data

# %%
import pandas as pd

# %%
df = pd.read_excel('../dataset/main.xlsx')
df.shape
# Out:
# (36791, 18)

# %%
df['views'] = df.pop('views')

# %%
df.head(3)
# Out:
#   trending_date                                              title  \
# 0    2017-11-14  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...
# 1    2017-11-14  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...
# 2    2017-11-14  Stylish Star Allu Arjun @ ChaySam Wedding Rece...
#
#      channel_title  category_id publish_time  \
# 0  Lokdhun Punjabi            1     12:20:39
# 1          HJ NEWS           25     05:43:56
# 2             TFPC           24     15:48:08
#
#                                                 tags  likes  dislikes  \
# 0  sharry mann|"sharry mann new song"|"sharry man...  33966       798
# 1  पीरियड्स के समय|"पेट पर पति करता ऐसा"|"देखकर द...    735       904
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...   2011       243
#
#    comment_count  comments_disabled  ratings_disabled  video_error_or_removed  \
# 0            882              False             False                   False
# 1              0               True             False                   False
# 2            149              False             False                   False
#
#                                          description  No_tags  desc_len  \
# 0  Presenting Sharry Mann latest Punjabi Song  Cu...       15       920
# 1  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...       19      2232
# 2  Watch Stylish Star Allu Arjun @ ChaySam Weddin...       14       482
#
#    len_title publish_date    views
# 0         81   2017-11-12  1096327
# 1         58   2017-11-13   590101
# 2         58   2017-11-12   473988

# %%
numeric_columns = df.select_dtypes(include=['number']).columns
categorical_columns = df.select_dtypes(include=['object', 'category', 'bool']).columns

# %%
df[numeric_columns].describe()
# Out:
#         category_id         likes      dislikes  comment_count       No_tags  \
# count  36791.000000  3.679100e+04  3.679100e+04   36791.000000  36791.000000
# mean      21.552173  2.745069e+04  1.685363e+03    2714.022043     18.938463
# std        6.586716  9.783129e+04  1.619732e+04   14978.114328      9.843531
# min        1.000000  0.000000e+00  0.000000e+00       0.000000      1.000000
# 25%       23.000000  8.790000e+02  1.090000e+02      83.000000     12.000000
# 50%       24.000000  3.126000e+03  3.310000e+02     336.000000     19.000000
# 75%       24.000000  1.409500e+04  1.032000e+03    1314.500000     25.000000
# max       43.000000  2.912710e+06  1.545017e+06  827755.000000     72.000000
#
#            desc_len     len_title         views
# count  36791.000000  36791.000000  3.679100e+04
# mean     923.079123     70.609361  1.071490e+06
# std      815.038867     22.409174  3.207149e+06
# min        3.000000      5.000000  4.024000e+03
# 25%      368.000000     53.000000  1.256040e+05
# 50%      677.000000     74.000000  3.078360e+05
# 75%     1237.000000     91.000000  8.066315e+05
# max     5136.000000    100.000000  1.254322e+08

# %%
df[numeric_columns].corr()
# Out:
#                category_id     likes  dislikes  comment_count   No_tags  \
# category_id       1.000000 -0.127137 -0.042272      -0.035696 -0.000233
# likes            -0.127137  1.000000  0.494518       0.780445  0.019600
# dislikes         -0.042272  0.494518  1.000000       0.708100  0.033725
# comment_count    -0.035696  0.780445  0.708100       1.000000  0.020227
# No_tags          -0.000233  0.019600  0.033725       0.020227  1.000000
# desc_len         -0.148119  0.065086  0.035031       0.031604  0.177760
# len_title        -0.163273 -0.170257 -0.030300      -0.119092  0.041871
# views            -0.183014  0.850073  0.543310       0.674151  0.055327
#
#                desc_len  len_title     views
# category_id   -0.148119  -0.163273 -0.183014
# likes          0.065086  -0.170257  0.850073
# dislikes       0.035031  -0.030300  0.543310
# comment_count  0.031604  -0.119092  0.674151
# No_tags        0.177760   0.041871  0.055327
# desc_len       1.000000   0.159658  0.122142
# len_title      0.159658   1.000000 -0.051559
# views          0.122142  -0.051559  1.000000

# %% [markdown]
# Kolom no_tags dan len_title memiliki korelasi yang sangat kecil terhadap views, sehingga tidak akan memberikan pengaruh yang signifikan terhadap prediksi views. Maka dari itu no_tags dan len_title layak untuk di drop

# %%
df[categorical_columns].describe()
# Out:
#        trending_date                                              title  \
# count          36791                                              36791
# unique           205                                              16431
# top       2017-12-23  Mission: Impossible - Fallout (2018) - Officia...
# freq             199                                                 19
#
#        channel_title publish_time    tags comments_disabled ratings_disabled  \
# count          36791        36791   36791             36791            36791
# unique          1390        12375   12463                 2                2
# top        VikatanTV     04:30:00  [none]             False            False
# freq             284          333    1120             35611            36034
#
#        video_error_or_removed  \
# count                   36791
# unique                      2
# top                     False
# freq                    36780
#
#                                               description
# count                                               36746
# unique                                              13979
# top     Subscribers Link: http://bit.ly/2qb69dZ\n\nCon...
# freq                                                  166

# %% [markdown]
# Kolom comments_disabled, ratings_disabled, video_error_or_removed merupakan kategorikal biner dan terlalu dominan pada satu kategori saja. Maka dari itu, kolom ini kemungkinan besar tidak memberikan dampak yang signifikan terhadap data dan layak untuk di drop

# %% [markdown]
# ## Feature Enginering

# %% [markdown]
# ### Dropping low-significant feature

# %%
df = df.drop(columns=['comments_disabled', 'ratings_disabled', 'video_error_or_removed', 'No_tags', 'len_title'])

# %% [markdown]
# ### Dropping Text feature

# %% [markdown]
# Kolom title, tag, dan description merupakan feature kalimat yang tidak dapat diproses oleh model. Maka dari itu untuk pemmbuatan model kali ini, kolom-kolom ini akan di drop

# %%
df = df.drop(columns=['title', 'tags', 'description'])

# %% [markdown]
# ### Ranking Channel Title

# %% [markdown]
# Channel title merupakan column kategorikal yang harus di preprocess untuk menjadi numerik agar bisa dimengerti oleh model.
#
# Terdapat 1390 jenis channel title sehingga one hot encodding tidak bisa dilakukan karena akan membuat dimensi fitur menjadi sangat besar.
#
# Oleh karena itu feature engineering akan dilakukan dengan menggunakan label encoding berdasarkan urutan rata-rata views tiap channel dari yang terbesar hingga terkecil.

# %%
df_channel = df.groupby('channel_title').agg({
    'views' : ['mean']
}).reset_index()

df_channel_sorted = df_channel.sort_values(by=('views', 'mean'), ascending=False)
df_channel_sorted = df_channel_sorted.reset_index(drop=True)

df_channel_sorted
# Out:
#                     channel_title         views
#                                            mean
# 0               YouTube Spotlight  8.226435e+07
# 1                 TaylorSwiftVEVO  2.864121e+07
# 2     Sony Pictures Entertainment  2.271359e+07
# 3                    FoxStarHindi  2.251442e+07
# 4            Marvel Entertainment  1.969840e+07
# ...                           ...           ...
# 1385                      Pakkatv  1.344300e+04
# 1386                 Reporter Roy  1.181600e+04
# 1387               Viral in India  1.139100e+04
# 1388          Wide Angle Pictures  1.133700e+04
# 1389             OneVision Telugu  1.032750e+04
#
# [1390 rows x 2 columns]

# %%
channel_label_dict = dict(zip(df_channel_sorted['channel_title'], df_channel_sorted.index + 1))

# %%
df['channel_title'] = df['channel_title'].map(channel_label_dict)
df.head(3)
# Out:
#   trending_date  channel_title  category_id publish_time  likes  dislikes  \
# 0    2017-11-14            101            1     12:20:39  33966       798
# 1    2017-11-14            149           25     05:43:56    735       904
# 2    2017-11-14            708           24     15:48:08   2011       243
#
#    comment_count  desc_len publish_date    views
# 0            882       920   2017-11-12  1096327
# 1              0      2232   2017-11-13   590101
# 2            149       482   2017-11-12   473988

# %% [markdown]
# Channel title sudah bertipe numeric

# %% [markdown]
# ### Datetime Feature Engineering

# %%
df['publish_time'] = pd.to_datetime(df['publish_time'], format='%H:%M:%S', errors='coerce')
df['trending_date'] = pd.to_datetime(df['trending_date'], errors='coerce')

# %% [markdown]
# hari, bulan, dan tahun dapat diambil dari Date waktu trending dan waktu publish

# %%
df['trending_day'] = df['trending_date'].dt.day
df['trending_month'] = df['trending_date'].dt.month
df['trending_year'] = df['trending_date'].dt.year

df['publish_day'] = df['publish_date'].dt.day
df['publish_month'] = df['publish_date'].dt.month
df['publish_year'] = df['publish_date'].dt.year

# %% [markdown]
# Selain itu pada publish hour, akan diambil waktu jamnya saja

# %%
df['publish_hour'] = df['publish_time'].dt.hour

# %% [markdown]
# Setelah melakukan ekstraksi, kolom lama akan dihapus karena bertipe datetime dan sudah tidak dipakai lagi

# %%
df = df.drop(columns=['trending_date', 'publish_time', 'publish_date'])

# %% [markdown]
# Berikut adalah hasil akhir dari feature engineering

# %%
df
# Out:
#        channel_title  category_id  likes  dislikes  comment_count  desc_len  \
# 0                101            1  33966       798            882       920
# 1                149           25    735       904              0      2232
# 2                708           24   2011       243            149       482
# 3                224           23  70353      1624           2684       263
# 4                431           24    492       293             66       753
# ...              ...          ...    ...       ...            ...       ...
# 36786            222           23   3291       404            196       818
# 36787            801           24   1726       478           1428       468
# 36788            572           24   1216       453            697      2187
# 36789           1073           24    698       115             65       432
# 36790            348           24  22466      1609           1205      1030
#
#          views  trending_day  trending_month  trending_year  publish_day  \
# 0      1096327            14              11           2017           12
# 1       590101            14              11           2017           13
# 2       473988            14              11           2017           12
# 3      1242680            14              11           2017           12
# 4       464015            14              11           2017           13
# ...        ...           ...             ...            ...          ...
# 36786   214378            14               6           2018           13
# 36787   406828            14               6           2018           13
# 36788   386319            14               6           2018           13
# 36789   130263            14               6           2018           13
# 36790  1278249            14               6           2018           10
#
#        publish_month  publish_year  publish_hour
# 0                 11          2017            12
# 1                 11          2017             5
# 2                 11          2017            15
# 3                 11          2017             7
# 4                 11          2017             1
# ...              ...           ...           ...
# 36786              6          2018             8
# 36787              6          2018            11
# 36788              6          2018             5
# 36789              6          2018            15
# 36790              6          2018             4
#
# [36791 rows x 14 columns]

# %%
df.to_excel('../dataset/preprocess.xlsx')
